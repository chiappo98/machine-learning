# %% [markdown]
# # <font color='red'>Classification on MNIST (part 2A: a simple NN)</font>

# %% [markdown]
# Import MNIST (NOTE: _not_ as we did it before..)

# %%
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %% [markdown]
# Check what we imported.

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
train_images.dtype
# Out:
# dtype('uint8')

# %%
test_images.dtype
# Out:
# dtype('uint8')

# %%
len(train_labels)
# Out:
# 60000

# %%
len(test_labels)
# Out:
# 10000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# The workflow will be as follows:
# 1.   we’ll feed the training data, `train_images` and `train_labels`, to the NN. The network will then learn to associate images and labels.
# 2.   we’ll ask the NN to produce predictions for `test_images`, and we’ll verify whether these predictions match the labels from `test_labels`.

# %%
# the network architecture
from tensorflow.keras import models
from tensorflow.keras import layers
my_network = models.Sequential([
  layers.Dense(350, activation='relu'),
  layers.Dense(350, activation='relu'),
  layers.Dense(350, activation='relu'),
  layers.Dense(10, activation='softmax')
])

# %% [markdown]
# A **layer** is a data-processing module that you can think of as a filter for data. Layers extract *representations* out of the data fed into them.

# %% [markdown]
# In this specific case, our NN consists of:
#
# *   a sequence of two `Dense` layers, which are `densely connected` (also called *fully connected*) neural layers
# *   the second (and last) layer is a bit special: it is a 10-way `softmax` layer, which will return an array of 10 numbers, our *probability scores* (summing to 1).

# %% [markdown]
# To make the network ready for training, we need to pick 3 more things, in the compilation step:
#
# *   A **loss function** (`loss` below)
# *   An **optimizer** (`optimizer` below)
# *   Some **metrics** (`metrics` below)

# %%
# the compilation step
my_network.compile(optimizer='rmsprop',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# %% [markdown]
# Before training, we’ll preprocess the data by reshaping it into the shape the network expects and scaling it so that all values are in the [0, 1] interval.

# %%
# Preparing the image data
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
#
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
train_images.dtype
# Out:
# dtype('float32')

# %%
test_images.shape
# Out:
# (10000, 784)

# %%
test_images.dtype
# Out:
# dtype('float32')

# %% [markdown]
# We’re now ready to train the network, via the `fit` method.

# %%
# %%time
# Fit the NN
#my_network.fit(train_images, train_labels, epochs=10, batch_size=128)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 7.39 µs

# %% [markdown]
# Two quantities are displayed during training:
#
# *   the loss of the network over the training data
# *   the accuracy of the network over the training data.
#
# We quickly reach a high accuracy e.g. 0.98 or 0.99 (98% or 99%) on the training data.
#
# Now let’s check that the model performs well on the test set, too:

# %%
#test_loss, test_acc = my_network.evaluate(test_images, test_labels)
#print('test_acc:', test_acc)

# %% [markdown]
# The test set accuracy should turn out to be a bit lower than the training set accuracy. This gap between training accuracy and test accuracy is an example of overfitting.

# %% [markdown]
# Being careful to do the training only once and properly, you can comment the fit instruction above, in oprder to esploit the onebelow here, and rerun the notebook from scratch to benefit of pandas superpowers and get a nice viz of the training process.

# %%
import pandas as pd

# %%
# %%time
history_callback = my_network.fit(train_images, train_labels, epochs=50, batch_size=128)
pd.DataFrame(history_callback.history).plot()
# Out:
# Epoch 1/50
# 469/469 [==============================] - 7s 4ms/step - loss: 0.2558 - accuracy: 0.9212
# Epoch 2/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0922 - accuracy: 0.9718
# Epoch 3/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0609 - accuracy: 0.9812
# Epoch 4/50
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0418 - accuracy: 0.9869
# Epoch 5/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0335 - accuracy: 0.9899
# Epoch 6/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0255 - accuracy: 0.9918
# Epoch 7/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0203 - accuracy: 0.9936
# Epoch 8/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0177 - accuracy: 0.9947
# Epoch 9/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0146 - accuracy: 0.9952
# Epoch 10/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0127 - accuracy: 0.9960
# Epoch 11/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9967
# Epoch 12/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 13/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0086 - accuracy: 0.9972
# Epoch 14/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0070 - accuracy: 0.9978
# Epoch 15/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0059 - accuracy: 0.9982
# Epoch 16/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 17/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 18/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 19/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 20/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0046 - accuracy: 0.9988
# Epoch 21/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 22/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 23/50
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 24/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 25/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 26/50
# 469/469 [==============================] - 1s 3ms/step - loss: 9.6252e-04 - accuracy: 0.9997
# Epoch 27/50
# 469/469 [==============================] - 1s 3ms/step - loss: 8.9693e-04 - accuracy: 0.9998
# Epoch 28/50
# 469/469 [==============================] - 1s 3ms/step - loss: 3.5541e-04 - accuracy: 0.9999
# Epoch 29/50
# 469/469 [==============================] - 1s 3ms/step - loss: 7.4144e-04 - accuracy: 0.9998
# Epoch 30/50
# 469/469 [==============================] - 1s 3ms/step - loss: 5.4131e-04 - accuracy: 0.9998
# Epoch 31/50
# 469/469 [==============================] - 1s 3ms/step - loss: 5.2357e-04 - accuracy: 0.9999
# Epoch 32/50
# 469/469 [==============================] - 2s 4ms/step - loss: 5.9669e-05 - accuracy: 1.0000
# Epoch 33/50
# 469/469 [==============================] - 2s 4ms/step - loss: 4.2852e-05 - accuracy: 1.0000
# Epoch 34/50
# 469/469 [==============================] - 1s 3ms/step - loss: 2.0986e-06 - accuracy: 1.0000
# Epoch 35/50
# 469/469 [==============================] - 1s 3ms/step - loss: 1.1654e-06 - accuracy: 1.0000
# Epoch 36/50
# 469/469 [==============================] - 1s 3ms/step - loss: 1.0085e-06 - accuracy: 1.0000
# Epoch 37/50
# 469/469 [==============================] - 1s 3ms/step - loss: 9.0830e-07 - accuracy: 1.0000
# Epoch 38/50
# 469/469 [==============================] - 1s 3ms/step - loss: 8.3565e-07 - accuracy: 1.0000
# Epoch 39/50
# 469/469 [==============================] - 1s 3ms/step - loss: 7.7831e-07 - accuracy: 1.0000
# Epoch 40/50
# 469/469 [==============================] - 2s 4ms/step - loss: 7.3099e-07 - accuracy: 1.0000
# Epoch 41/50
# 469/469 [==============================] - 2s 4ms/step - loss: 6.9087e-07 - accuracy: 1.0000
# Epoch 42/50
# 469/469 [==============================] - 1s 3ms/step - loss: 6.5582e-07 - accuracy: 1.0000
# Epoch 43/50
# 469/469 [==============================] - 1s 3ms/step - loss: 6.2544e-07 - accuracy: 1.0000
# Epoch 44/50
# 469/469 [==============================] - 2s 3ms/step - loss: 5.9837e-07 - accuracy: 1.0000
# Epoch 45/50
# 469/469 [==============================] - 1s 3ms/step - loss: 5.7420e-07 - accuracy: 1.0000
# Epoch 46/50
# 469/469 [==============================] - 1s 3ms/step - loss: 5.5224e-07 - accuracy: 1.0000
# Epoch 47/50
# 469/469 [==============================] - 1s 3ms/step - loss: 5.3229e-07 - accuracy: 1.0000
# Epoch 48/50
# 469/469 [==============================] - 2s 4ms/step - loss: 5.1395e-07 - accuracy: 1.0000
# Epoch 49/50
# 469/469 [==============================] - 2s 4ms/step - loss: 4.9706e-07 - accuracy: 1.0000
# Epoch 50/50
# 469/469 [==============================] - 1s 3ms/step - loss: 4.8142e-07 - accuracy: 1.0000
# CPU times: user 1min 30s, sys: 6.82 s, total: 1min 36s
# Wall time: 2min 22s
# <Axes: >

# %%
test_loss, test_acc = my_network.evaluate(test_images, test_labels)
print('test_acc:', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1198 - accuracy: 0.9864
# test_acc: 0.9864000082015991
